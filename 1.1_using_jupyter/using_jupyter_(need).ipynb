# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 Getting ready

# %% [markdown]
# Hi!
#
# This is some code to calculate: $y = x^2$
#
# HAHAHAHA
# HAHAHAHA
# HAHAHAHA
# HAHAHAHA

# %%
for i in range(1,11):
    for j in range (1,11):
        print(f"{i*j:4}", end="")     #the :4} tells Python to have at least 4 spaces per thing i*j (to accomodate for double digit numbers)
                                     # the ', end="") tells Python that after every iteration of j in i*j (wnere i remains the same for 1<=j<=10 since the j loop is nested in the i loop) to continue on the same line rather than the default enter
    print()                        # the number of print() tells how many spaces between each row....if you want an n amount of spaces have print("\n")
# Out:
#    1   2   3   4   5   6   7   8   9  102
#    2   4   6   8  10  12  14  16  18  202
#    3   6   9  12  15  18  21  24  27  302
#    4   8  12  16  20  24  28  32  36  402
#    5  10  15  20  25  30  35  40  45  502
#    6  12  18  24  30  36  42  48  54  602
#    7  14  21  28  35  42  49  56  63  702
#    8  16  24  32  40  48  56  64  72  802
#    9  18  27  36  45  54  63  72  81  902
#   10  20  30  40  50  60  70  80  90 1002

# %% [markdown]
# # TO MAKE A TABLE:
# |A    | B    | C   |
# | :-- | :--: | --: |
# | a_1 | a_2  | a_3 |

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # 2 Getting started with Jupyter

# %% [markdown]
# ## 2.1 It is all about running cells

# %% [markdown]
# ## 2.2 A traditional start

# %% [markdown]
# # 3 All about Markdown

# %% [markdown]
# ## 3.1 Rendering Markdown cells

# %% [markdown]
# ## 3.2 Some basic syntax

# %% [markdown]
# Hi!
#
# This is some code to calculate: $y = x^2$
#
# HAHAHAHA
# HAHAHAHA
# HAHAHAHA
# HAHAHAHA

# %% [markdown]
# ## 3.3 Headings

# %% [markdown]
# # HEADING
# ## HEADING
# ### HEADING

# %% [markdown]
# ## 3.4 Displaying Code

# %% [markdown]
# ```python
#     print('Hello World')
# ```

# %% [markdown]
# ## 3.5 Links

# %% [markdown]
# TO LEARN PYTHON/MARKDOWN SYNTAX:
#
# https://sps.nus.edu.sg/python/

# %% [markdown]
# ## 3.6 Images

# %% [markdown]
# ![](https://static.wixstatic.com/media/b4fa82_1fe2d5f68dbe403595d6bdf00e2008bb~mv2.jpg/v1/fill/w_980,h_653,al_c,q_85,usm_0.66_1.00_0.01,enc_avif,quality_auto/b4fa82_1fe2d5f68dbe403595d6bdf00e2008bb~mv2.jpg)

# %% [markdown]
# ## 3.7 Tables

# %% [markdown]
# |A    | B    | C   |
# | :-- | :--: | --: |
# | a_1 | a_2  | a_3 |

# %% [markdown]
# ## 3.8 Lists

# %% [markdown]
# ## 3.9 Equations

# %% [markdown]
# $ y = x^2 + πx + e^x $

# %% [markdown]
# ## Footnotes
