# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Functions (Need) Exercises</span></div>

# %%
import numpy as np

# %% [markdown]
# ## Exercise 1: Do you know why?

# %% [markdown]
# The following code works as expected despite not having an else statement. Please use a Markdown cell to explain why?

# %%
def greeting(name):
    if name == 'Batman':
        return 'Hello Batman! So, nice to meet you!'
    return f'Hello {name}!'

# %% [markdown]
# **Answer**: Because regardless of what the name is there is an output associated to it already, if I put the name 'Rijul', the output will be 'Hello Rijul!', whereas the if statement is only there to put a condition on a specific name, here being 'Batman'.

# %% [markdown]
# ## Exercise 2: Chubby or not?

# %%
weight = float(input('What is your weight in kg?  '))
height = float(input('What is your height in m?  '))

def calculate_bmi(weight, height):
    bmi = weight/height**2
    print(f'BMI: {bmi:.2f}')

    if bmi<18.5:
        print('Category: Underweight')
    elif 18.5 <= bmi <= 24.9:
        print('Category: Normal weight')
    elif 25 <= bmi <= 29.9:
        print('Category: Overweight')
    else:
        print('Category: Obese')

calculate_bmi(weight, height)
# Out:
# BMI: 22.50
# Category: Normal weight

# %% [markdown]
# ## Exercise 3: Factorials

# %%
def factorial(n):
    if n<0:
        print('INVALID INPUT')
    elif n!=0:
        result = 1
        for i in range(1,n+1):
            result *= i
        return result
    else:
        return 1

factorial(5)
# Out:
# 120
