# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good), Exercises</span></div>

# %% [markdown]
# ## Learning to interrupt

# %%
while True:
    print('*', end=' ')

    break
# Out:
# *

# %% [markdown]
# Can interrupt by pressing the pause button on the left of the code cell, and then to prevent an infinite while loop write a condition such that the loop breaks.

# %% [markdown]
# ## Resetting & Restarting the Kernal

# %%
print = 'PRINT'

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# ## Timing Stuff

# %%
squares = [i**2 for i in range(10)]
print(squares)

# %%timeit
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# UsageError: Line magic function `%%timeit` not found.

# %%
squares = list()
for i in range (10):
    squares.append(i**2)

print(squares)
# %%timeit
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# UsageError: Line magic function `%%timeit` not found.

# %% [markdown]
# ## Footnotes
