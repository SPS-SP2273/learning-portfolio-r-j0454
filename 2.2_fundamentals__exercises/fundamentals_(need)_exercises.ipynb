# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Need) Exercises</span></div>

# %% [markdown]
# # # Exercise 1
# Basic features of python:
# 1. functions
#
# 2. variables
#
# 3. libraries (e.g. numpy, astropy, math)
#
# 4. lists (1D and 2D) (they use '[]' bracket)
#
# 5. dictionaries (use {}), print a term/definition using:
#     ```python
#     print(dictionary_name['term'])
#     ```
#
# 6. *= vs == in python, one is to assign a variable with something, the other is a comparative question*
#
# 7. *if statements to make decisions*
#
# 8. *importance of indentations*
#
# 9. *() bracket used for functions to pass arguments within, and in math, and tuples; [] used for lists, {} used for dictionaries*

# %% [markdown]
# ## Exercise 2: Debugging code

# %%
#x, y = 3, 4
        #z = sqrt(x*2 + y**2)
    #Print(x, y, z)

# %%
import numpy as np

x, y = 3, 4

z = np.sqrt(x**2 + y**2)

print(x, y, z)
# Out:
# 3 4 5.0

# %% [markdown]
# ## Exercise 3: Definitions
# |**#**|  **Term**  |  **Description** |
# |-|--------|--------------|
# |1| Function | code that executes a specific task |
# |2| Arguments | inputs to functions |
# |3| Comments  | Notes which do not impact function of code, improves readability of code |
# |4| Indentations | helps the interpretter read blocks of code (similar to brackets in other languages like c++)|
# |5| . | defines ownership, e.g. np.sqrt() is numpy's square root function, whereas math.sqrt() is the math library's square root function|
# |6| [] | used to define a list |
# |7| [[],[]] | for 2D lists |
# |8| {} | used to define dictionaries |

# %% [markdown]
# ## Exercise 4: More than one way to divide

# %%
#10%4 #remainder function
# Out:
# 5
