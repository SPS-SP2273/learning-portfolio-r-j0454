# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %%
import os
import glob
import shutil

# %% [markdown]
# ## Task 1 & 2

# %%
os.getcwd()

#Specifying location of data folder:
data_folder = '/Users/rijul/Downloads/CODING/os-collaboration-exercise-data'


txt_files = glob.glob(os.path.join(data_folder, "*.txt"))     # *.txt tells python to only join files with extension .txt to the data_folder:)

# %%
# Define function to convert filename:
def convert_filename(filename):
    
    name, extension = filename.split('.')
    name = filename.replace(".txt", "")

    #if file already renamed:
    if name[0:2].isdigit() and name[3:5].isdigit() and name[2] == "-":
        return filename
    
    else: 
        month_dict = {
        'jan': '01', 'feb': '02', 'mar': '03',
        'apr': '04', 'may': '05', 'jun': '06',
        'jul': '07', 'aug': '08', 'sep': '09',
        'oct': '10', 'nov': '11', 'dec': '12'
        }

        #Split filename
        month_day, city = name.split('_')
        month, day = month_day.split('-')

        #Convert month
        month_number = month_dict[month.lower()]

        #change filename:
        new_filename = f"{month_number}-{day}_{city}.{extension}"
        return new_filename


convert_filename("oct-08_singapore.txt")
# Out:
# '10-08_singapore.txt'

# %% [markdown]
# ## Task 3

# %%
# Using a for loop to convert following list of filenames:
file_name_list = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

for filename in file_name_list:
    print(f'{filename} ---> {convert_filename(filename)}')
# Out:
# oct-08_singapore.txt ---> 10-08-singapore.txt
# jul-10_cairo.txt ---> 07-10-cairo.txt
# may-15_dhaka.txt ---> 05-15-dhaka.txt
# may-13_cairo.txt ---> 05-13-cairo.txt
# oct-21_cairo.txt ---> 10-21-cairo.txt
# jan-10_singapore.txt ---> 01-10-singapore.txt
# jun-20_tokyo.txt ---> 06-20-tokyo.txt
# aug-06_jakarta.txt ---> 08-06-jakarta.txt
# dec-21_karachi.txt ---> 12-21-karachi.txt
# jan-01_tokyo.txt ---> 01-01-tokyo.txt

# %% [markdown]
# ## Task 4

# %%
#Use glob to rename all files in the folder

for old_path in txt_files:
    old_file_name = os.path.basename(old_path)
    new_file_name = convert_filename(old_file_name)
    
    # Skip if already renamed
    if old_file_name == new_file_name:
        print(f"Skipped (already renamed): {old_file_name}")
        continue
    
    new_path = os.path.join(os.path.dirname(old_path), new_file_name)
    
    if os.path.exists(old_path):   # only rename if the file exists
        os.rename(old_path, new_path)
        print(f"Renamed: {old_file_name} → {new_file_name}")

# %% [markdown]
# ## Task 5

# %%
cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

cityfolder_path = '/Users/rijul/Downloads/CODING/os-collaboration-exercise-data'

# For every city, create a path using Path.join
for city in cities:
    folder_path = os.path.join(cityfolder_path, city.lower())

# And for each of those paths make a folder/directory, and say created folder to indicate completion
    os.mkdir(folder_path)
    print(f"Created folder: {folder_path}")
# Out:
# Created folder: /Users/rijul/Downloads/CODING/os-collaboration-exercise-data/cairo
# Created folder: /Users/rijul/Downloads/CODING/os-collaboration-exercise-data/dhaka
# Created folder: /Users/rijul/Downloads/CODING/os-collaboration-exercise-data/jakarta
# Created folder: /Users/rijul/Downloads/CODING/os-collaboration-exercise-data/karachi
# Created folder: /Users/rijul/Downloads/CODING/os-collaboration-exercise-data/manila
# Created folder: /Users/rijul/Downloads/CODING/os-collaboration-exercise-data/melbourne
# Created folder: /Users/rijul/Downloads/CODING/os-collaboration-exercise-data/osaka
# Created folder: /Users/rijul/Downloads/CODING/os-collaboration-exercise-data/shanghai
# Created folder: /Users/rijul/Downloads/CODING/os-collaboration-exercise-data/singapore
# Created folder: /Users/rijul/Downloads/CODING/os-collaboration-exercise-data/tokyo

# %% [markdown]
# ## Task 6

# %%
# Path of the folder named 'cairo' in data_folder as a variable:
cairo_folder = os.path.join(data_folder, 'cairo')

# Selects all files that have 'cairo.txt'. in them
cairo_files = glob.glob(os.path.join(data_folder, '*cairo.txt'))

print(cairo_files)
# Out:
# ['/Users/rijul/Downloads/CODING/os-collaboration-exercise-data/12-03_cairo.txt', '/Users/rijul/Downloads/CODING/os-collaboration-exercise-data/01-30_cairo.txt', '/Users/rijul/Downloads/CODING/os-collaboration-exercise-data/11-14_cairo.txt', '/Users/rijul/Downloads/CODING/os-collaboration-exercise-data/04-21_cairo.txt', '/Users/rijul/Downloads/CODING/os-collaboration-exercise-data/05-27_cairo.txt', '/Users/rijul/Downloads/CODING/os-collaboration-exercise-data/12-17_cairo.txt', '/Users/rijul/Downloads/CODING/os-collaboration-exercise-data/01-05_cairo.txt', '/Users/rijul/Downloads/CODING/os-collaboration-exercise-data/08-18_cairo.txt', '/Users/rijul/Downloads/CODING/os-collaboration-exercise-data/05-12_cairo.txt', '/Users/rijul/Downloads/CODING/os-collaboration-exercise-data/12-22_cairo.txt', '/Users/rijul/Downloads/CODING/os-collaboration-exercise-data/07-17_cairo.txt', '/Users/rijul/Downloads/CODING/os-collaboration-exercise-data/04-14_cairo.txt', '/Users/rijul/Downloads/CODING/os-col
# ...

# %%
# Makes a copy of each selected file in cairo_files in cairo_folder
for file_path in cairo_files:
    shutil.copy(file_path, cairo_folder)
    print(f'Copied {file_path} ----> {cairo_folder}')

# %% [markdown]
# ## Task 7

# %%
# Now for all cities in cities:

for city in cities:
    # Destination city folders defined
    city_folder = os.path.join(data_folder, city)

    # find all files with corresponding city name
    city_files = glob.glob(os.path.join(data_folder, f'*{city.lower()}.txt'))

    # makes copies of each file path in city_files in the corresponding city_folder
    for file_path in city_files:
        shutil.copy(file_path, city_folder)
        print(f'Copied {file_path} ----> {city_folder}')
