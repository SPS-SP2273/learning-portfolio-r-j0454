# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Good)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 There is more to if

# %% [markdown]
# There are situations where we may need more conditions, more branches to the
# ```python
# if
# ```
# statement

# %%
name = 'Batman'

if name == 'Batman':
    print('Hello Batman!')
elif name == 'Robin':
    print('Hello Sidekick!')
else:
    print('Hello World!')
# Out:
# Hello Batman!

# %% [markdown]
# # 2 Asking questions

# %% [markdown]
# To use if to make decisions we need to be able to ask questions; some of which might be complicated.
#
# Some questions about the following two lists:

# %%
fruits = ['apple', 'banana', 'pineapple', 'jackfruit']
vegetables = ['celery', 'potato', 'broccoli', 'kale']

# %%
'apple' in fruits       #is 'apple' in fruits? returns a boolean
# Out:
# True

# %% [markdown]
# ## 2.1 Asking Math questions

# %% [markdown]
# # 3 Python stores information in different formats or types

# %% [markdown]
# # 4 Never compare floats directly

# %% [markdown]
# ## 4.1 The Problem

# %%
a=.1
a3=0.3
print(f'{a=}')
# Out:
# a=0.1

# %%
print(f'{a=:.17f} and {a3=:.19f}')     #prints to 17 and 19 dp
# Out:
# a=0.10000000000000001 and a3=0.2999999999999999889

# %% [markdown]
# Notice how the output of a3 is not 0.3000000 but .299999....
# so when you ask if a3 == a, the console will output FALSE

# %%
3*a==a3
# Out:
# False

# %% [markdown]
# ## 4.2 A solution

# %% [markdown]
# Can use numpy to fix this

# %%
import numpy as np

np.isclose(3*a, a3)
# Out:
# np.True_

# %% [markdown]
# # 5 Combining English and variables

# %%
text = "Test"
f'{text:<50}'
# Out:
# 'Test                                              '

# %% [markdown]
# ## 5.1 Structure of f-strings

# %% [markdown]
# # 6 Escape sequences

# %% [markdown]
# ## 6.1 Self-documenting f-strings

# %% [markdown]
# f strings

# %% [markdown]
# DON'T NEED PRINT FUNCTION FOR VARIABLES

# %%
#python also allows:
x=y=10
x
y
# Out:
# 10

# %%
x = 40
x = x + 40
x

#can also just write: 
x+=40 
x
# Out:
# 120

# %% [markdown]
# # 7 Computers read = from Right to Left!

# %% [markdown]
# # 8 Shorter and Cleaner Code

# %% [markdown]
# # 9 Python can be a prima-donna.

# %% [markdown]
# # 10 Best Practices for Scientific Computing

# %% [markdown]
# # 11 Looking for help

# %% [markdown]
# ## References

# %% [markdown]
# ## Footnotes
