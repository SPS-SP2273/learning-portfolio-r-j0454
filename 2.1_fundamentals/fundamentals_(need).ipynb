# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 Functions

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# A function in Python is something that executes a specific task
# - Parentheses always follow a function
# - Most functions expect arguments to pass in, which are written within the parentheses, e.g. print() which is a function built into Python:
# - ```python
#     print('Hello World')
#     ```
# - Can also define our own functions—an extremely useful tool later on.

# %% [markdown]
# # 2 Python is interpreted

# %% [markdown]
# Python as we refer to it is really the interpreter which works *sequentially*, one command at a time. So the interpretter basically throws a hissy fit if there is an error in the command currently being executed.

# %% [markdown]
# # 3 Python is sensitive.

# %% [markdown]
# e.g.: Python is case sensitive:
# ```python
#     print('Hello World')
# ```
# the above WILL work
#
# BUT
#
# ```python
#     Print('Hello World')
# ```
#
# WILL NOT work

# %% [markdown]
# # 4 Comments

# %%
## this is a comment
# this is also a comment, this whole line after the '#' is now not code, to code move to the next line

# %% [markdown]
# Comments are mainly used to help future me understand what my code is supposed to do (say I have a clunky function I'll probably forget the purpose of later)

# %% [markdown]
# # 5 = is not the same as ==

# %%
#e.g.:

x = 5
print(x)

#but == is asking a QUESTION:
if x == 5:
    print('x is equal to 5')
else:
    print("I don't know what x is")
# Out:
# 5
# x is equal to 5

# %% [markdown]
# # 6 Use if to make decisions

# %% [markdown]
# *shown in the above code*

# %% [markdown]
# # 7 Indentations (spaces) are sooo IMPORTANT!

# %% [markdown]
# For consistency just use TAB please

# %% [markdown]
# # 8 ‘age’ is English, age is a variable.

# %%
print('age') # this will print the word 'age'
age = 25 # this is the variable age = 25
print(age) # the VALUE of age will be printed
# Out:
# age
# 25

# %% [markdown]
# # 9 Brackets

# %%
print('Hello!')  # In functions
(1 + 2) * 5       # For math

# %%
py_list = [1, 2, 3, 4, 5]   # [] for a 1D list

py_list_2 = [               # [] for a 2D list
                [1, "A"],      
                [2, "B"],
                [3, "C"],
                [4, "D"],
                [5, "E"]
            ]

# %%
personal_info = {
    'Names': 'Batman',
    'Real Name': 'Bruce Wayne',
    'Age': 55,
    'Affiliation': 'Justice League',
    'Universe': 'DC'
}

# %% [markdown]
# The above is a DICTIONARY, Notice that the dictionary uses a key to identify a value (e.g., ‘Real Name’ ‘Bruce Wayne’).
# This is a neat (and super useful) way to store data and quickly access information; for example:

# %%
print(personal_info['Real Name'])

# %% [markdown]
# here [] is used to fetch a definition, so here 'Bruce Wayne' will be printed.

# %% [markdown]
# # 10 Giving Python superpowers with Packages

# %% [markdown]
# ## 10.1 Some Context

# %%
sqrt(4)

# %% [markdown]
# The sqrt() function does not exist in base python, so must import libraries like numpy or math as done below:

# %%
import math

math.sqrt(4)
# Out:
# 2.0

# %% [markdown]
# ## 10.2 Importing the math package

# %% [markdown]
# *done above*

# %% [markdown]
# ## 10.3 Importing the numpy package

# %%
import numpy as np  #write np because writing numpy before the .sqrt or anything is too time consuming

np.sqrt(4)
# Out:
# np.float64(2.0)

# %% [markdown]
# ## 10.4 Why so many packages?

# %% [markdown]
# # 11 The dot (.)

# %% [markdown]
# ## Footnotes
